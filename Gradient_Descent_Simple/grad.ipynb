# %%
# %pip install numpy
# %pip install matplotlib
# Out:
# Requirement already satisfied: numpy in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in z:\programming\dsa\python\notebooks\gradient_descent_simple\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Simple cost function: f(x) = x^2
def cost_function(x):
    return x**2
 
# Gradient descent implementation
def gradient_descent(learning_rate=0.1, iterations=100):
    x = 10 # Starting point
    history = [x]
    
    for i in range(iterations):
        gradient = 2*x  # Derivative of x^2 is 2x
        x = x - learning_rate * gradient
        history.append(x)
    
    return history
 
# Run gradient descent
history = gradient_descent()
 
# Plot results
plt.plot(history)
plt.xlabel('Iteration')
plt.ylabel('Parameter Value')
plt.title('Gradient Descent Optimization')
plt.show()

# %% [markdown]
# The code shows GD for
# $$
# f=(x)^2
# $$
# When high lr the graph diverges, it can even oscilate, changing other values mostly only changes the shape of the graph
